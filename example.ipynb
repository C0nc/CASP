# %%
import scanpy as sc 
import squidpy as sq
from CASP import CASP

adata = sc.read_h5ad('keren1.h5ad')
casp = CASP(adata)
# Out:
# Method : LiNGAM
# *** Causal Estimate ***
#
# ## Identified estimand
# Estimand type: EstimandType.NONPARAMETRIC_ATE
#
# ### Estimand : 1
# Estimand name: backdoor
# Estimand expression:
#    d
# ───────(E[CD138|CD4,dsDNA,Vimentin])
# d[EGFR]
# Estimand assumption 1, Unconfoundedness: If U→{EGFR} and U→CD138 then P(CD138|EGFR,CD4,dsDNA,Vimentin,U) = P(CD138|EGFR,CD4,dsDNA,Vimentin)
#
# ## Realized estimand
# b: CD138~EGFR+CD4+dsDNA+Vimentin+EGFR*PD1+EGFR*CD31
# Target units: ate
#
# ## Estimate
# Mean value: 0.8294200359313938
# p-value: [0.]
#
# Refute: Add a random common cause
# Estimated effect:0.8294200359313938
# New effect:0.8294129184204284
# p value:0.94

# %%
casp.causal_discovery()

# %%
casp.refute_relation(treatment='EGFR', outcome='CD138')
